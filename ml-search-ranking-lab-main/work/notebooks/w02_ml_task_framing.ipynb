# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# This is a ranking and scoring task. We want to order content pages based on their relevance and potential for growth so we can systematically prioritize which ones need an optimization refresh first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# 90-day future impressions (impressions_90d) as a proxy for content demand and visibility.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# NDCG (Normalized Discounted Cumulative Gain) or Rank Correlation (Spearman’s Rho) to ensure our sorted list aligns with actual high-performing content.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

# Load the data
df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

# Show the unit of analysis using the correct column name
print(f"Total rows (units of analysis): {len(df):,}")
display(df[['content_id', 'search_volume', 'competition', 'cpc']].head(3))
# Out:
# Total rows (units of analysis): 30,000
#              content_id  search_volume  competition   cpc
# 0  content_304f48230142           10.0         0.67  2.05
# 1  content_a1fb4e703a9e           90.0         0.01  0.05
# 2  content_9aa793d4d895            0.0         0.00  0.00

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule (like a rigid static threshold) is too blunt and ignores complex, non-linear interactions between traffic, historical impressions, and engagement patterns. Machine learning can dynamically weigh multiple signals simultaneously to surface high-impact opportunities.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
